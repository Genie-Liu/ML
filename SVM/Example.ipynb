# %%
import svmMLiA
from importlib import reload
import numpy as np

import matplotlib  
import matplotlib.pyplot as plt 

reload(svmMLiA)
# Out:
# <module 'svmMLiA' from 'D:\\Documents\\ML\\ML\\SVM\\svmMLiA.py'>

# %%
# 导入数据
dataMat, labelMat = svmMLiA.loadDataSet('testSet.txt')

# %%
# 目视化数据

f1 = plt.figure(1)
n = len(dataMat)
p1x = []
p1y = []
p2x = []
p2y = []
for i in range(n):
    if labelMat[i] == '1':
        p1x.append(dataMat[i][0])
        p1y.append(dataMat[i][1])
    else:
        p2x.append(dataMat[i][0])
        p2y.append(dataMat[i][1])
plt.scatter(p1x, p1y, color='r')
plt.scatter(p2x, p2y, color='b')
plt.show()

# %%
# 训练模型
b, alphas = svmMLiA.smoSimple(dataMat, labelMat, 0.6, 0.001, 40)
# Out:
# iter: 0 i:0, pairs changed 1
# iter: 0 i:4, pairs changed 2
# iter: 0 i:8, pairs changed 3
# L==H
# L==H
# L==H
# iter: 0 i:24, pairs changed 4
# j not moving enough
# j not moving enough
# L==H
# iter: 0 i:30, pairs changed 5
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# iter: 0 i:54, pairs changed 6
# iter: 0 i:55, pairs changed 7
# iter: 0 i:73, pairs changed 8
# j not moving enough
# iter: 0 i:94, pairs changed 9
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# iter: 0 i:55, pairs changed 1
# j not moving enough
# j not moving enough
# j not moving enough
# iter: 0 i:0, pairs changed 1
# iter: 0 i:4, pairs changed 2
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# iter: 0 i:29, pairs changed 3
# ...

# %%
f1 = plt.figure(1)
n = len(dataMat)
p1x = []
p1y = []
p2x = []
p2y = []
for i in range(n):
    if labelMat[i] == '1':
        p1x.append(dataMat[i][0])
        p1y.append(dataMat[i][1])
    else:
        p2x.append(dataMat[i][0])
        p2y.append(dataMat[i][1])
plt.scatter(p1x, p1y, color='r')
plt.scatter(p2x, p2y, color='b')

svmx = []
svmy = []
m = alphas.shape[0]
for i in range(m):
    if alphas[i] > 0:
        svmx.append(dataMat[i][0])
        svmy.append(dataMat[i][1])
plt.scatter(svmx, svmy, color='y',marker='o',s=30)


plt.show()
